# %%
# Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['mse','mae','friedman_mse'],
'max_features': ['auto','sqrt','log2'],
'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
# print best parameter after tuning
# print (grid.best_params_)
re = grid.cv_results_

from sklearn.metrics import r2_score

# Fit the model
grid.fit(independent, dependent)

# Predict on same data
y_pred = grid.predict(independent)

# Compute R²
r_score = r2_score(dependent, y_pred)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# The R_score value for best parameter {'criterion': 'mae', 'max_features': 'auto', 'splitter': 'best'}: 0.998667156135576

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.011140      0.000989         0.005518        0.000453
# 1        0.009722      0.003887         0.005320        0.001447
# 2        0.009529      0.000901         0.005626        0.001286
# 3        0.009837      0.001921         0.006526        0.001309
# 4        0.013636      0.003704         0.006326        0.000751
# 5        0.009226      0.001787         0.005615        0.000587
# 6        0.045006      0.002639         0.003606        0.000583
# 7        0.031262      0.001168         0.004612        0.002040
# 8        0.026963      0.005583         0.004310        0.000752
# 9        0.024555      0.002075         0.004210        0.000253
# 10       0.029973      0.004500         0.004621        0.000585
# 11       0.024471      0.005957         0.004518        0.000554
# 12       0.011228      0.001473         0.004515        0.000556
# 13       0.007521      0.001267         0.004005        0.000316
# 14       0.007016      0.001001         0.003608        0.000585
# 15       0.005915      0.000370         0.004110        0.000864
# 16       0.007223      0.000401         0.004002        0.000316
# 17       0.005512      0.001134         0.002605        0.000370
#
#    param_criterion param_max_features param_splitter  \
# 0              mse               auto           best
# 1              mse               auto         random
# 2              mse               sqrt           best
# 3              mse               sqrt         random
# 4              mse               log2           best
# 5              mse               log2         random
# 6              mae               auto           best
# 7              mae               auto         random
# 8              mae               sqrt           best
# 9              mae               sqrt         random
# 10             mae               log2           best
# 11             mae               log2         random
# 12    friedman_mse               auto           best
# 13    friedman_mse               auto         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.718196
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.728721
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.764174
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.609276
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.723336
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.679821
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.740715
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.683748
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.595314
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.710404
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.705467
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.641376
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.713512
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.745292
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.731505
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.692938
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.612774
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.683677
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.605707           0.722595           0.736028
# 1            0.642006           0.711335           0.697761
# 2            0.678084           0.671003           0.690111
# 3            0.590244           0.663495           0.661223
# 4            0.624560           0.741704           0.766542
# 5            0.435340           0.598029           0.676444
# 6            0.593748           0.700814           0.736132
# 7            0.600405           0.767620           0.735638
# 8            0.565939           0.613251           0.663544
# 9            0.633232           0.698070           0.668526
# 10           0.623602           0.494096           0.707521
# 11           0.639375           0.645053           0.499027
# 12           0.644121           0.728385           0.741138
# 13           0.651596           0.731236           0.762504
# 14           0.597843           0.559833           0.653691
# 15           0.393165           0.414625           0.654431
# 16           0.642514           0.605917           0.716745
# 17           0.605247           0.766548           0.682379
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.655323         0.687570        0.049506                8
# 1            0.748425         0.705650        0.036075                5
# 2            0.717567         0.704188        0.033936                6
# 3            0.683009         0.641449        0.035387               14
# 4            0.723619         0.715952        0.048349                2
# 5            0.719445         0.621816        0.101212               17
# 6            0.759337         0.706149        0.059305                4
# 7            0.752322         0.707947        0.060741                3
# 8            0.706229         0.628855        0.050034               16
# 9            0.626315         0.667309        0.033605               10
# 10           0.755343         0.657206        0.091897               12
# 11           0.759897         0.636946        0.082740               15
# 12           0.675413         0.700514        0.035795                7
# 13           0.752358         0.728597        0.039823                1
# 14           0.703177         0.649210        0.063768               13
# 15           0.485922         0.528216        0.123283               18
# 16           0.720283         0.659647        0.049628               11
# 17           0.647748         0.677120        0.053097                9

# %%
age_input=float(input("Age: "))
bmi_input=float(input("BMI: "))
children_input=float(input("Children: "))
sex_male_input=int(input("Sex Male 0 or 1: "))
smoker_yes_input=int(input("Smoker Yes 0 or 1: "))
# Out:
# Age: 43
# BMI: 32
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[33209.95965686]

# %%
# Importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\programdata\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

# Define the parameter grid for tuning
param_grid = {
    'n_estimators': [50, 100],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

# Create the GridSearchCV object
grid = GridSearchCV(
    estimator=XGBRegressor(objective='reg:squarederror'),
    param_grid=param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)

# Fit the model on the full dataset
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7], 'n_estimators': [50, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
# print (grid.best_params_)
re = grid.cv_results_

from sklearn.metrics import r2_score

# Fit the model
grid.fit(independent, dependent)

# Predict on same data
y_pred = grid.predict(independent)

# Compute R²
r_score = r2_score(dependent, y_pred)
print("The R_score value for best parameter {}:".format(grid.best_params_), r_score)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# The R_score value for best parameter {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}: 0.8802518725875269

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.116814      0.020345         0.009321        0.000402
# 1        0.134468      0.008721         0.010330        0.001168
# 2        0.094271      0.039496         0.010727        0.002491
# 3        0.113906      0.011196         0.009695        0.001233
# 4        0.091970      0.012276         0.007721        0.000401
# 5        0.175393      0.018176         0.009618        0.000808
# 6        0.046635      0.003510         0.009628        0.001406
# 7        0.060370      0.003449         0.008614        0.000803
# 8        0.057428      0.003282         0.008414        0.000931
# 9        0.090634      0.010722         0.009734        0.000982
# 10       0.100501      0.013714         0.010635        0.001314
# 11       0.154200      0.005658         0.009236        0.000511
# 12       0.046031      0.005493         0.010533        0.002400
# 13       0.064042      0.004930         0.010735        0.001571
# 14       0.053477      0.001722         0.009028        0.000899
# 15       0.086051      0.004466         0.011333        0.002470
# 16       0.093360      0.007228         0.008227        0.001943
# 17       0.098359      0.013821         0.005212        0.000510
#
#    param_learning_rate param_max_depth param_n_estimators  \
# 0                 0.01               3                 50
# 1                 0.01               3                100
# 2                 0.01               5                 50
# 3                 0.01               5                100
# 4                 0.01               7                 50
# 5                 0.01               7                100
# 6                  0.1               3                 50
# 7                  0.1               3                100
# 8                  0.1               5                 50
# 9                  0.1               5                100
# 10                 0.1               7                 50
# 11                 0.1               7                100
# 12                 0.2               3                 50
# 13                 0.2               3                100
# 14                 0.2               5                 50
# 15                 0.2               5                100
# 16                 0.2               7                 50
# 17                 0.2               7                100
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.551672
# 1   {'learning_rate': 0.01, 'max_depth': 3, 'n_est...           0.760272
# 2   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...           0.552009
# 3   {'learning_rate': 0.01, 'max_depth': 5, 'n_est...           0.758440
# 4   {'learning_rate': 0.01, 'max_depth': 7, 'n_est...           0.546052
# 5   {'learning_rate': 0.01, 'max_depth': 7, 'n_est...           0.748675
# 6   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.882706
# 7   {'learning_rate': 0.1, 'max_depth': 3, 'n_esti...           0.877827
# 8   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.871417
# 9   {'learning_rate': 0.1, 'max_depth': 5, 'n_esti...           0.864447
# 10  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...           0.850612
# 11  {'learning_rate': 0.1, 'max_depth': 7, 'n_esti...           0.838871
# 12  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...           0.876863
# 13  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...           0.867868
# 14  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...           0.862461
# 15  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...           0.849009
# 16  {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...           0.843757
# 17  {'learning_rate': 0.2, 'max_depth': 7, 'n_esti...           0.829836
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.518092           0.529814           0.540705
# 1            0.708444           0.738133           0.736334
# 2            0.520179           0.531872           0.540813
# 3            0.709164           0.742269           0.735720
# 4            0.521982           0.527914           0.540246
# 5            0.707782           0.732395           0.731741
# 6            0.813817           0.892385           0.853029
# 7            0.810826           0.891714           0.848998
# 8            0.802986           0.889836           0.843672
# 9            0.794779           0.882467           0.833990
# 10           0.792116           0.868604           0.829207
# 11           0.778532           0.855527           0.816955
# 12           0.810272           0.891669           0.849653
# 13           0.800057           0.883093           0.847861
# 14           0.793482           0.878756           0.832805
# 15           0.770143           0.859542           0.821411
# 16           0.772489           0.842147           0.818822
# 17           0.754265           0.822334           0.812771
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.539840         0.536025        0.011327               17
# 1            0.744497         0.737536        0.016814               14
# 2            0.540244         0.537023        0.010579               16
# 3            0.743768         0.737872        0.016161               13
# 4            0.536615         0.534562        0.008614               18
# 5            0.736825         0.731484        0.013317               15
# 6            0.869898         0.862367        0.027625                1
# 7            0.862317         0.858337        0.027764                2
# 8            0.864221         0.854427        0.029666                4
# 9            0.855876         0.846312        0.030117                6
# 10           0.847933         0.837694        0.025987                8
# 11           0.839685         0.825914        0.026683               10
# 12           0.860610         0.857814        0.027726                3
# 13           0.853364         0.850449        0.028013                5
# 14           0.852166         0.843934        0.029301                7
# 15           0.840592         0.828139        0.031577                9
# 16           0.842224         0.823888        0.027320               11
# 17           0.832366         0.810314        0.028843               12

# %%
age_input=float(input("Age: "))
bmi_input=float(input("BMI: "))
children_input=float(input("Children: "))
sex_male_input=int(input("Sex Male 0 or 1: "))
smoker_yes_input=int(input("Smoker Yes 0 or 1: "))
# Out:
# Age: 43
# BMI: 32
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[40364.637]
